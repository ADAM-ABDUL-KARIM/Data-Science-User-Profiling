# %%
import pandas as pd

df = pd.read_csv('MergedForWeka(1).csv')
df
# Out:
#          App Category  Usage (hours)  Access count
# 0        Social Media            329          6141  \
# 1       Communication            145          6366
# 2       Communication            105          5843
# 3              Gaming             85           545
# 4       Entertainment             82          1275
# 5   Internet Browsing             43           501
# 6           Elearning             26           411
# 7   Internet Browsing             26           230
# 8   Internet Browsing             22          1256
# 9       Entertainment             18           440
# 10      Entertainment             17           210
# 11           Shopping             11           526
# 12          Elearning              8          1024
# 13           Delivery              8           268
# 14           Delivery              8           338
# 15          Elearning              7           105
#
#     average_time_per_access (Minutes)  average_time_per_day (Minutes)
# ...

# %%
totalTimePerDay= df['average_time_per_day (Minutes)'].sum()
totalTimePerDay
# Out:
# 292.227979239

# %%
if totalTimePerDay > 240:
    print("User has high screen time")
else:
    print("User has low screen time")
# Out:
# User has high screen time
